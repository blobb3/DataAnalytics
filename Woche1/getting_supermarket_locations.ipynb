# %% [markdown]
# # Getting all available Swiss supermarkets using overpass Web API

# %% [markdown]
# ### Overpass turbo query to get all available supermarkets in Switzerland

# %%
from pandas import json_normalize
import requests
import json

# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)
df.head(5)
# Out:
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225154  8.969868       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.source:addr tags.opening_date tags.postid tags.diet:local  \
# 0              NaN               NaN         NaN             NaN
# 1              NaN               NaN         NaN             NaN
# 2              NaN               NaN         NaN             NaN
# 3              NaN               NaN         NaN             NaN
# 4              NaN               NaN         NaN             NaN
#
#   tags.payment:account_cards tags.diet:fish tags.diet:mediterranean  \
# 0                        NaN            NaN                     NaN
# 1                        NaN            NaN                     NaN
# 2                        NaN            NaN                     NaN
# 3                        NaN            NaN                     NaN
# 4                        NaN            NaN                     NaN
#
#   tags.diet:organic tags.diet:seafood tags.recycling:low_energy_bulbs
# 0               NaN               NaN                             NaN
# 1               NaN               NaN                             NaN
# 2               NaN               NaN                             NaN
# 3               NaN               NaN                             NaN
# 4               NaN               NaN                             NaN
#
# [5 rows x 249 columns]

# %% [markdown]
# ### Plot supermarkets on map

# %%
import folium
import pandas as pd

# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"] == 'Migros']
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#           lat       lon tags.brand    tags.shop
# 1   47.226191  8.980329     Migros  supermarket
# 4   47.375020  8.522895     Migros  supermarket
# 7   47.491874  8.706448     Migros  supermarket
# 11  47.344749  8.529981     Migros  supermarket
# 16  47.375255  8.536107     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d8e8699d776f291eef8be15bd05ee84 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d8e8699d776f291eef8be15bd05ee84&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d8e8699d776f291eef8be15bd05ee84 = L.map(
#                 &quot;map_4d8e8699d776f291eef8be15bd05ee84&quot;,
#                 {
#                     center: [47.01883755856874, 7.990184917514123],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4d8e8699d776f291eef8be15bd05ee84);
#
#
#
#
#
#             var tile_layer_63c002181e01a2087b2ee8ff26e9d855 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_63c002181e01a2087b2ee8ff26e9d855.addTo(map_4d8e8699d776f291eef8be15bd05ee84);
#
#
#             var marker_e67deae2d2c139dd14c221c807094400 = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_4d8e8699d776f291eef8be15bd05ee84);
#
#
#         var popup_532cd27b24e90058fc5ee178c57b8b91 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb8f48824cf6bf53e8fdc886ce9af333 = $(`&lt;div id=&quot;html_bb8f48824cf6bf53e8fdc886ce9af333&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_532cd27b24e90058fc5ee178c57b8b91.setContent(html_bb8f48824cf6bf53e8fdc886ce9af333);
#
#
#
#         marker_e67deae2d2c139dd14c221c807094400.bindPopup(popup_532cd27b24e90058fc5ee178c57b8b91)
#         ;
#
#
#
#
#             var marker_a4e2279d6dd66a8bb0d963f82768b47e = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_4d8e8699d776f291eef8be15bd05ee84);
#
#
#         var popup_2b0f7c2ceaa5b7210551cd89bc80c0ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad8991806aab8e170aaa4c5ca515e2a6 = $(`&lt;div id=&quot;html_ad8991806aab8e170aaa4c5ca515e2a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_2b0f7c2ceaa5b7210551cd89bc80c0ca.setContent(html_ad8991806aab8e170aaa4c5ca515e2a6);
#
#
#
#         marker_a4e2279d6dd66a8bb0d963f82768b47e.bindPopup(popup_2b0f7c2ceaa5b7210551cd89bc80c0ca)
#         ;
#
#
#
#
#             var marker_3dd171ba5926693a3b36fdb7c9ef04f7 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_4d8e8699d776f291eef8be15bd05ee84);
#
#
#         var popup_0149e242c80f67356f89c82b74e83209 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a351a9bde116bb59cd707332c616ac6b = $(`&lt;div id=&quot;html_a351a9bde116bb59cd707332c616ac6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_0149e242c80f67356f89c82b74e83209.setContent(html_a351a9bde116bb59cd707332c616ac6b);
#
#
#
#         marker_3dd171ba5926693a3b36fdb7c9ef04f7.bindPopup(popup_0149e242c80f67356f89c82b74e83209)
#         ;
#
#
#
#
#             var marker_3c9d743d545441004ec57b894672d934 = L.marker(
#                 [47.3447487, 8.5299814],
#                 {}
#             ).addTo(map_4d8e8699d776f291eef8be15bd05ee84);
#
#
#         var popup_afadc1ffd27ddedb76c46612d550db4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_854c425fbc3f469ad7622472a6120605 = $(`&lt;div id=&quot;html_854c425fbc3f469ad7622472a6120605&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_afadc1ffd27ddedb76c46612d550db4e.setContent(html_854c425fbc3f469ad7622472a6120605);
#
#
#
#         marker_3c9d743d545441004ec57b894672d934.bindPopup(popup_afadc1ffd27ddedb76c46612d550db4e)
#         ;
#
#
#
#
#             var marker_91f43604b2e16e1748e2c3fb9a1267b9 = L.marker(
#                 [47.3752549, 8.5361073],
#                 {}
#             ).addTo(map_4d8e8699d776f291eef8be15bd05ee84);
#
#
#         var popup_24e110f17f30259d7c8773258f33817c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19a502a5ee2922e7b0424f8985f7cf84 = $(`&lt;div id=&quot;html_19a502a5ee2922e7b0424f8985f7cf84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_24e110f17f30259d7c8773258f33817c.setContent(html_19a502a5ee2922e7b0424f8985f7cf84);
#
#
#
#         marker_91f43604b2e16e1748e2c3fb9a1267b9.bindPopup(popup_24e110f17f30259d7c8773258f33817c)
#         ;
#
#
#
#
#             var marker_d273c43e797f13f4b4c98ed3ec0337e3 = L.marker(
#                 [47.2406357, 8.7239602],
#                 {}
